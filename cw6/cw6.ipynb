# %%
import os
os.system(r"C:\Users\kayajiva\mystem.exe -cgid --format xml C:\Users\kayajiva\futur.txt C:\Users\kayajiva\futur10.xml")
# Out:
# 0

# %%
if not os.path.exists(r'C:/Users/kayajiva/newspaper/plain/2018/9/'):
    os.makedirs(r'C:/Users/kayajiva/newspaper/plain/2018/9')
    
if not os.path.exists(r'C:/Users/kayajiva/newspaper/mystem-plain/2018/9/'):
    os.makedirs(r'C:/Users/kayajiva/newspaper/mystem-plain/2018/9')
    
if not os.path.exists(r'C:/Users/kayajiva/newspaper/mystem-xml/2018/9/'):
    os.makedirs(r'C:/Users/kayajiva/newspaper/mystem-xml/2018/9')
    
f = open(r"C:/Users/kayajiva/newspaper/plain/2018/9/article1.txt", "w", encoding="utf-8")  
f.write('Народный артист России и Украины Александр Малинин проводит в Пензе свой выходной 18 октября.')
f.close()


os.system("C:/Users/kayajiva/mystem.exe -cgid C:/Users/kayajiva/newspaper/plain/2018/9/article1.txt C:/Users/kayajiva/newspaper/mystem-plain/2018/9/article1.txt")
os.system("C:/Users/kayajiva/mystem.exe -cgid --format xml C:/Users/kayajiva/newspaper/plain/2018/9/article1.txt C:/Users/kayajiva/newspaper/mystem-xml/2018/9/article1.xml")
# Out:
# 0

# %%
import urllib.request
url = 'https://www.pravda-news.ru/news/kultura/v-penze-tragifars-vassa-i-drugie-stal-vtoroy-premeroy-v-dramteatre/'  # адрес страницы, которую мы хотим скачать
user_agent = 'Mozilla/5.0 (Windows NT 6.1; Win64; x64)'  # хотим притворяться браузером

req = urllib.request.Request(url, headers={'User-Agent':user_agent})  
# добавили в запрос информацию о том, что мы браузер Мозилла

with urllib.request.urlopen(req) as response:
   html = response.read().decode('utf-8')
print(html)
# Out:
# <!DOCTYPE html>
# <html lang="ru">
# <head>
# 	<meta charset="UTF-8">
# 	<title>В Пензе драмтеатр представил премьеру трагифарса «Васса и другие»</title>
# 	<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">
# 	<meta name="format-detection" content="telephone=no">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge">
# 		<meta name="keywords" content="васса и другие пенза драмтеатр премьера альбина смелова васса железнова максим горький" />
# 	<meta name="description" content="В среду, 17 октября, на сцене пензенского драмтеатра прошла премьера трагифарса «Васса и другие» по пьесе Максима Горького «Васса Железнова»." />
#
#
#
#
# 	<link rel="icon" href="/favicon.ico" type="image/x-icon">
# 	<link rel="shortcut icon" href="/favicon.ico" type="image/x-icon">
#
#
# 	<link href="/bitrix/cache/css/s1/PP/kernel_main/kernel_main.css?153729747929161" type="text/css"  rel="stylesheet">
# ...

# %%
import re
regPostTitle = re.compile('<h1>.+?</h1>', flags= re.DOTALL)
titles = regPostTitle.findall(html)
print(titles)
new_titles = []
regTag = re.compile('<.*?>', re.DOTALL)
regSpace = re.compile('\s{2,}', re.DOTALL)
for t in titles:
    clean_t = regSpace.sub("", t)
    clean_t = regTag.sub("", clean_t)
    new_titles.append(clean_t)
for t in new_titles:
    print(t)
# Out:
# ['<h1>В Пензе драмтеатр представил премьеру трагифарса «Васса и другие»</h1>']
# В Пензе драмтеатр представил премьеру трагифарса «Васса и другие»
